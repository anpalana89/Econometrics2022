# %%
import numpy as np
import pandas as pd
import matplotlib_inline as plt
import seaborn as sns
# %matplotlib inline
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
df = pd.read_csv("Cancer.csv")

# %%
df
# Out:
#            Id Diagnosis  Radius (mean)  Texture (mean)  Perimeter (mean)  \
# 0     8510426         B         13.540           14.36             87.46
# 1     8510653         B         13.080           15.71             85.63
# 2     8510824         B          9.504           12.44             60.34
# 3      854941         B         13.030           18.42             82.61
# 4    85713702         B          8.196           16.84             51.71
# ..        ...       ...            ...             ...               ...
# 564    926125         M         20.920           25.09            143.00
# 565    926424         M         21.560           22.39            142.00
# 566    926682         M         20.130           28.25            131.20
# 567    926954         M         16.600           28.08            108.30
# 568    927241         M         20.600           29.33            140.10
#
#      Area (mean)  Smoothness (mean)  Compactness (mean)  Concavity (mean)  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 32 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Id                         569 non-null    int64
#  1   Diagnosis                  569 non-null    object
#  2   Radius (mean)              569 non-null    float64
#  3   Texture (mean)             569 non-null    float64
#  4   Perimeter (mean)           569 non-null    float64
#  5   Area (mean)                569 non-null    float64
#  6   Smoothness (mean)          569 non-null    float64
#  7   Compactness (mean)         569 non-null    float64
#  8   Concavity (mean)           569 non-null    float64
#  9   Concave points (mean)      569 non-null    float64
#  10  Symmetry (mean)            569 non-null    float64
#  11  Fractal dimension (mean)   569 non-null    float64
#  12  Radius (se)                569 non-null    float64
# ...

# %%
df_new = df[["Fractal dimension (mean)","Area (mean)","Radius (mean)", "Texture (mean)", "Smoothness (mean)", "Diagnosis"]]

# %%
df_new
# Out:
#      Fractal dimension (mean)  Area (mean)  Radius (mean)  Texture (mean)  \
# 0                     0.05766        566.3         13.540           14.36
# 1                     0.06811        520.0         13.080           15.71
# 2                     0.06905        273.9          9.504           12.44
# 3                     0.05863        523.8         13.030           18.42
# 4                     0.06503        201.9          8.196           16.84
# ..                        ...          ...            ...             ...
# 564                   0.06879       1347.0         20.920           25.09
# 565                   0.05623       1479.0         21.560           22.39
# 566                   0.05533       1261.0         20.130           28.25
# 567                   0.05648        858.1         16.600           28.08
# 568                   0.07016       1265.0         20.600           29.33
#
#      Smoothness (mean) Diagnosis
# 0              0.09779         B
# ...

# %%
sns.pairplot(data = df_new,hue = "Diagnosis")

# %%
df_new.describe()
# Out:
#        Fractal dimension (mean)  Area (mean)  Radius (mean)  Texture (mean)  \
# count                569.000000   569.000000     569.000000      569.000000
# mean                   0.062798   654.889104      14.127292       19.289649
# std                    0.007060   351.914129       3.524049        4.301036
# min                    0.049960   143.500000       6.981000        9.710000
# 25%                    0.057700   420.300000      11.700000       16.170000
# 50%                    0.061540   551.100000      13.370000       18.840000
# 75%                    0.066120   782.700000      15.780000       21.800000
# max                    0.097440  2501.000000      28.110000       39.280000
#
#        Smoothness (mean)
# count         569.000000
# mean            0.096360
# std             0.014064
# min             0.052630
# 25%             0.086370
# 50%             0.095870
# 75%             0.105300
# max             0.163400
